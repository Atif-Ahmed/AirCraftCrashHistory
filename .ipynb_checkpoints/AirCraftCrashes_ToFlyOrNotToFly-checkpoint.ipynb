# %% [markdown]
# # Data Analytics Based on History of Aircraft Crashes since 1908
#
# ## <font color="darkorange"> Goal: To justify whether it is safer to take the aircraft nowadays. Supporting decision with data <font>
# <font color="navy">
# This dataset contains the information about the aircraft crashes happened since 1908 until 2009. Dataset provides the time, data location, route, passanger counts, summary and other useful information regarding aircraft crashes. The goal is to detemine if it is safe to travel by aircraft now a days.
#
# ### Summary
# The notebook first perform some data exploration to determine the dataset feature and to analyze if they can prove to be useful in our decision making. The notebook then uses regession method to predict various data patterns in near future which can help in determining the safety of aircraft. At the end a brief summary is discussed about the final conclusion.

# %% [markdown]
# <font color="navy">
# ### Importing the most commonly used Python libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.svm import SVR
import numpy as np
import calendar
import seaborn as sns
from IPython.display import display

sns.set()

# %% [markdown]
# <font color="navy">
# ### Reading the csv file

# %%
rootPath = "C:\MyStuff\Machine Learning\Kaggle\\aircraftCrashes"
filename = "\Airplane_Crashes_and_Fatalities_Since_1908.csv"
fullPath = rootPath + filename
dataFrame = pd.read_csv(fullPath)

# %% [markdown]
# - __
# # <font color="green">Data Exploration</font>
#
# <font color="navy">
# ### Understanding the Data in dataset
# Before jumping into data analysis first lets have a look at the information provided in the dataset itself.

# %%
dataFrame.sample(5)
# Out:
#             Date   Time                           Location  \
# 5077  12/23/2005  22:27               Nardaran, Azerbaijan
# 232   02/08/1931    NaN                Wairoa, New Zealand
# 1879  11/08/1963  17:59  Mariehamn, Aaland Island, Finland
# 1077  09/04/1950  14:10                    Utica, New York
# 522   08/13/1939  16:35             Rio de Janerio, Brazil
#
#                         Operator Flight #  \
# 5077         Azerbaijan Airlines      217
# 232           Dominion Air Lines      NaN
# 1879                     Finnair      217
# 1077           Robinson Airlines       32
# 522   Pan American World Airways      NaN
#
#                                      Route                        Type  \
# 5077  Baku, Azerbaijan - Aktau, Kazakhstan          Antonov AN-140-100
# 232                                    NaN                Desoutter II
# 1879                     Turku - Mariehamn                Douglas DC-3
# ...

# %% [markdown]
# - __
#
# ## <font color='green'> A quick overview of the dataset</font>

# %%
total,features = dataFrame.shape
print 'Total Number of recorded Crashes: \t' + str(total)
print 'Total Number of crash Features: \t' + str(features)
print '**********************************************'
print 'Initial Features List'
print dataFrame.dtypes
print ''
print '**********************************************'
print 'Total Number of missing data \n' 
print dataFrame.isnull().sum().sort_values()
print ''
print '**********************************************'
print
# Out:
# Total Number of recorded Crashes: 	5268
# Total Number of crash Features: 	13
# **********************************************
# Initial Features List
# Date             object
# Time             object
# Location         object
# Operator         object
# Flight #         object
# Route            object
# Type             object
# Registration     object
# cn/In            object
# Aboard          float64
# Fatalities      float64
# Ground          float64
# Summary          object
# dtype: object
#
# **********************************************
# Total Number of missing data
#
# Date               0
# Fatalities        12
# Operator          18
# Location          20
# Aboard            22
# Ground            22
# Type              27
# Registration     335
# Summary          390
# cn/In           1228
# Route           1706
# Time            2219
# Flight #        4199
# dtype: int64
#
# **********************************************

# %% [markdown]
#  <font color="navy">
# The data shows history of aircraft crashes. A total 5268 entries with 13 features with some missing data information specially in  Flight Number(4199 missing entries), Time(2219 entires are missing), Route(1706 missing entries).  Some of the most relevant data features are explained below.
#
# - __Date__ is the most crucial parameter for this data analysis. The Date feature contains information about the year, the month and the date of the crash.
# - __Fatalities__ contains the death count for each crash, this can be prove useful when determining the percentage of pessanger survial.
# - __Operator__ tells the name of flight operator, this feature can be useful when determining which airline are safer to travel with based on past history.
# - __Location__ tells the location of plane crash, this feature can tell some useful information about the safty of various regions during past years.
# - __Aboard__ total number of pessangers on the aircraft.
# - __Fatalities__ Passenger casulties during the aircraft crash.
# - __Ground__  Ground casulties involve in aircraft crash.
# - __Route__ can provide some insights regarding more dangerous regions with more flight casulties. Still are large number of data entries are missing however the information obtained from routes can prove to be useful.

# %% [markdown]
# - __
#
# ## <font color="green">Analyzing Flight Crashes over the years</font>

# %%
# Transform date information from string to standard date format
dataFrame['Date'] = pd.to_datetime(dataFrame['Date']) 

#extract "Year" from the date data and convert to np array
# This is one way of extracting data from the Pandas dataframe
planeCrashYear = dataFrame['Date'].apply(lambda x : x.year).values
years, frequency = np.unique(planeCrashYear,return_counts=True)


#plot the graphs for years and frequency using matplotlib and seaborn
fig = plt.figure(figsize=(18, 6))
ax1 = fig.add_subplot(1,1,1)
ax1.set_xticks(np.arange(years.min(),years.max(),2))
plt.xlim(years.min()-1, years.max()+1)
plt.xticks(rotation=90)
plt.bar(years,frequency,align="center",alpha=0.2)
plt.plot(years,frequency,'_',color="red",linewidth=1,marker='.')
plt.xlabel('Years')
plt.ylabel('Flight Crashes')
plt.grid(True)
plt.show()

# Predicting flight crashed in near future from 2009 using Support Vector Regression

YEARS_OF_PREDICTION = 15

X = [[i] for i in years]
svd_model = SVR(kernel='rbf',C=1e3,gamma= 0.005)
svd_model.fit(X,frequency)
predict = lambda i : svd_model.predict(i)
p_years = np.arange(years.min(),years.max()+YEARS_OF_PREDICTION+1,1).reshape(-1,1)
p_frequency = predict(p_years)

df_flightCrashPrediction = pd.DataFrame({'Years': p_years.flatten(),
                                         'Crashes': p_frequency}).set_index('Years')


## Predicting the flight crashes in coming years using Support Vector Regression from sklearn.
fig = plt.figure(figsize=(18, 6))
ax1 = fig.add_subplot(1,1,1)
ax1.set_xticks(np.arange(years.min(),years.max()+YEARS_OF_PREDICTION +2,2))
plt.xlim(years.min()-1, years.max()+YEARS_OF_PREDICTION+1)
plt.xticks(rotation=90)
plt.plot(years,frequency,color="red",linewidth=1,marker='.')
plt.plot(p_years,p_frequency,'--',color="blue",linewidth=1,marker='.')
plt.xlabel('Years')
plt.legend(['Actual AirCraft Crashes','Predicted AirCraft Crashes',])
plt.title("Aircraft Crashes Prediction in coming years using Support Vector Regression")

# %% [markdown]
#  <font color="navy">
#     __Conclusion:__ An overall rise in the flight crashes can be seen over the years since 1908 until 1970s. years between 1960s until 2000s have witnessed the most crashes. The graph shows an overall declining trend in aircraft crashes from 2000 on wards. The second graphs shows prediction of the flights until 2019. Support Vector Regression from sklearn is used with gamma = 0.005 to avoid overfitting the data. The prediction model shows much higher possibly of decline in aircraft accidents in coming years(from 2009) which directs towards safer travel with every passing year. It is to be noted the further the prediction goes away from the actual data the higher will be error, as can be seen for year 2018 the prediction model shows slight negative value and odd behavious of unexpected rise in flight crash incidences afterwards.</font>

# %% [markdown]
# - __
# ## <font color="green">Analyzing Flight Crashes over the months /Seasons</font>

# %%
#extract "Month" from the date - this time create a seperate data frame and the sort by month. 
planeCrashMonth = dataFrame.Date.map(lambda x : x.month).value_counts().to_frame().sort_index()
#plot the graphs for years and frequency
plt.figure(figsize=(16, 8))
color = ['#009BFF','#00F3FF','#04FF00','#04FF00','#BDFF00','#FF0000','#FF0000','#FF5900','#FFB600','#FFB600','#00F3FF']
plt.bar(planeCrashMonth.index,planeCrashMonth.Date,align="center",alpha=0.4,color=color)

plt.xticks(np.arange(14), calendar.month_name[0:13])

plt.title('Plot of aircraft accidents in each month - the color shows season of the year')
plt.xlabel('Months')
plt.ylabel('Flight Crashes')
plt.grid(True)

# %% [markdown]
#  <font color="navy">
# __Conclusion:__ An interesting pattern can be seen here, that aircraft crashes are most frequent during the winter season and least during the spring season.

# %% [markdown]
# - __
# ## <font color="green">Analyzing the Number of Passengers involved in the flight crashes over years</font>
#  <font color="navy"> Even though number of passengers on board cannot be considered as the parameter to predict aircraft incidences, However its a useful piece of information in finding the number passengers got affected by these aircraft incidences over the last century. as well as the increase or decrease in the safty measure over the years

# %%
# There are some NAN entires for Aboard and Ground columns and needs to be filled first. We will assume zero passengers on
# board for these entires so they doesnot effect the analysis.
dataFrame['Aboard'] = dataFrame['Aboard'].fillna(0)
dataFrame['Fatalities'] = dataFrame['Fatalities'].fillna(0)

#extract "Year" from the date - this time create a new column in the orignal dataframe.
dataFrame['Year'] = dataFrame.Date.map(lambda x : x.year)

passengerPerYear = dataFrame.groupby(['Year'])[["Aboard","Fatalities"]].sum()

plt.figure(figsize=(16, 8))
plt.bar(passengerPerYear.index,passengerPerYear["Aboard"],linewidth =0,width=0.4, align='center', color ='#4444ff')
plt.bar(passengerPerYear.index,passengerPerYear["Fatalities"],linewidth =0,width=0.4,align='center', color="#ff5555")
plt.plot(passengerPerYear.index,passengerPerYear["Aboard"],'_', mew = 5,color ='#44ff88')

plt.xlim(passengerPerYear.index.min()-1, passengerPerYear.index.max()+1)
plt.xticks(np.arange(passengerPerYear.index.min()-1, passengerPerYear.index.max()+1,2))
plt.xticks(rotation=90)
plt.grid(True)
plt.legend(['Total Passengers','Survivors','Fatalities'])
plt.xlabel('Years')
plt.ylabel('Total Passengers')
plt.show()


#computing the survival rate 
passengerPerYear['SurvivalRate']= ((passengerPerYear["Aboard"] - passengerPerYear["Fatalities"])/passengerPerYear["Aboard"])*100
plt.figure(figsize=(16, 7))

plt.bar(passengerPerYear.index, passengerPerYear.SurvivalRate,width=1,linewidth=0,align='center',alpha=0.7,
        bottom= (100-passengerPerYear.SurvivalRate),color ='#4444ff')
plt.bar(passengerPerYear.index,100 - passengerPerYear.SurvivalRate,width=1, linewidth=0,alpha=0.7, 
        color="#ff5555",align='center')


plt.xlim(passengerPerYear.index.min()-2, passengerPerYear.index.max()+2)
plt.xticks(np.arange(passengerPerYear.index.min(), passengerPerYear.index.max()+2,2))
plt.xticks(rotation=45)
plt.yticks(np.arange(0,101,10))
plt.grid(True)
plt.title("Passange Survival and Fatality ratio for each year")
plt.legend(["Survival Rate","Fatality Rate"],frameon=True)
plt.ylabel('Percentage (%)')
plt.xlabel('Years')
plt.show()


#predicting the survival rate of the passengers over the comming years.
X = [[i] for i in years]
svd_model = SVR(kernel='rbf',C=1e3,gamma= 0.005)
svd_model.fit(X,(100 - passengerPerYear['SurvivalRate']))
predict = lambda i : svd_model.predict(i)
p_years = np.arange(years.min(),years.max()+YEARS_OF_PREDICTION+1,1).reshape(-1,1)
p_fatality = predict(p_years)


plt.figure(figsize=(16, 7))
plt.bar(passengerPerYear.index, passengerPerYear.SurvivalRate,width=1,linewidth=0,align='center',alpha=0.7,
        bottom= (100-passengerPerYear.SurvivalRate),color ='#4444ff')
plt.bar(passengerPerYear.index,100 - passengerPerYear.SurvivalRate,width=1, linewidth=0,alpha=0.7, 
        color="#ff5555",align='center')
plt.plot(p_years,p_fatality,'--',color="lightgreen",linewidth=3,marker='.')

plt.xlim(years.min()-1, years.max()+YEARS_OF_PREDICTION+1)
plt.xticks(np.arange(years.min(),years.max()+YEARS_OF_PREDICTION +2,2))
plt.xticks(rotation=45)
plt.yticks(np.arange(0,101,10))
plt.grid(True)
plt.title("Passange Survival and Fatality ratio for each year")
plt.legend(["Predicted Fatality(%)","Survival Rate(%)","Fatality Rate(%)"],frameon=True)
plt.ylabel('Percentage (%)')
plt.xlabel('Years')
plt.show()

# %% [markdown]
#  <font color="navy">
# __Conclusion:__
# The graph shows the fatality rate has decreased and thus survival rate of passengers have increased over time. Even though the flight crashes become more frequent during mid 19th century however the survival rate of passangers is also showing a slight increase over the last few decades. A SVR based prediction model( with same gamma and error panelty values) as predict that the fatality rate in aircraft accidents are expect to decrease further in future. Similar to previous results the prediction accuracy drops drastically as the predition time move futher from the orignial data(timeline). </font>

# %% [markdown]
# - __
# ## <font color="green"> Other Interesting Data Analaysis based on Regions </font>
#  <font color="navy">
# Aircraft crashes based on region can also provide some useful insights about the data. This information can be used filter information for a specific region and do further analysis. However the Location feature in the dataset provides more specific geo-location. To get a more general region of interest, first some string operations are performed to generalize location at a larger scale (Country, Regions or States, e.t.c)

# %%
# Adding a new feature to hold the country of accident.
dataFrame['Location'] =  dataFrame['Location'].fillna(",")
dataFrame['Region'] = dataFrame.Location.map(lambda x: str(x).split(',')[-1].strip())
CrashByRegions = dataFrame.groupby('Region')['Region'].count()

print "TOP 10 REGIONS WITH HIGHEST FLIGHT CRASH HISTORY"
display(CrashByRegions.sort_values(ascending=False).head(10))
print " "
plt.figure(figsize=(16, 7))
brazil_flights = dataFrame[['Year']].loc[dataFrame.Region == 'Brazil'].groupby('Year')[['Year']].count()
plt.bar(brazil_flights.index, brazil_flights.values)
plt.xlabel('YEARS')
plt.ylabel('NUMBER OF CRASHES')
plt.title('CRASH HISTORY OF BRAZIL')
plt.grid(True)
plt.show()


print " This information can be used for getting the flight accident history based on regions such as Malaysia"
print " "
print "****************************     FLIGHT CRASH HISTORY OF MALAYSIA     ***********************************"
display(dataFrame[["Date","Aboard","Fatalities","Location","Summary"]].loc[dataFrame['Region'] == 'Malaysia'])
# Out:
# TOP 10 REGIONS WITH HIGHEST FLIGHT CRASH HISTORY
# Region
# Brazil        189
# Alaska        177
# Russia        175
# Canada        149
# Colombia      149
# California    143
# France        133
# England       105
# India          99
# China          88
# Name: Region, dtype: int64
#  This information can be used for getting the flight accident history based on regions such as Malaysia
#
# ****************************     FLIGHT CRASH HISTORY OF MALAYSIA     ***********************************
#            Date  Aboard  Fatalities  \
# 1075 1950-08-25    12.0        12.0
# 1202 1952-05-09    17.0        17.0
# 2905 1976-06-06    12.0        12.0
# 3002 1977-09-27    79.0        34.0
# 3016 1977-12-04   100.0       100.0
# 3827 1989-02-19     4.0         4.0
# 4038 1991-09-03    20.0        14.0
# 4196 1993-07-30    17.0         1.0
# 4365 1995-09-15    53.0        34.0
# 4379 1995-11-29    10.0        10.0
# 4515 1997-09-06    10.0        10.0
# ...

# %% [markdown]
# <font color='navy'>
# - __
#
# ## Final Conclusion
#
# The trends from various data features shows that the future of the aircraft is becoming more and more safer. From 2000 onwards the number of aircraft crashes are declining and are expect to go further down in coming years. On top of that, the fatality rate of aircraft accidents are also declining steadily. Thus it can be concluded based on the provided data the aircraft traveling is becoming more and more safer. However some regions are more safer than the others, forexample Brazil has shown the worst track record in aircraft safely and up until 2009 aircraft incidences are still relatively higher.
#
#  ### Improving decision making in detemining the safety of traveling via aircrafts with more data.
# The information provided in this dataset doesnot provide a very clear picture. It only provides information about the aircraft with crashed and same goes for the passengers boarding the aircraft. However the total number of operational aircrafts,flights and passangers traveling through aircraft are much more higher and is increasing. The dataset however doesnot provide any information regarding total number of aircraft flights over years. To precisely detemine the frequency of aircraft crashes and to detemine the level of safety of the aircarft over time, information of total number of aircraft flights is very crutial to further strenghten our claim.
#
# #### Example
# |Year|total Air Crashes| Total Air Flights|
# |----|-----------------|------------------|
# |a   | 30              |   100,000        |
# |b   | 100             |   100,000,000    |
#
# From this example it can be seen that even though in year b, the total number of aircraft crashes are more but the chances of flight accident is much less compared to a.
#
# $chances\,of\,flight\,crash\,in\,year\,a = \frac{30}{100,000} \times 100 = 0.03\%$
#
# $chances\,of\,flight\,crash\,in\,year\,b = \frac{100}{100,000,000} \times 100 = 0.0001\%$
#
# #### Importing More Data
# The worldbank provides the data for total number of flights taken place from year 1970 until 2016. Incorporating this data in our analysis will surely prove helpful in determining the measure of travel safty via aircraft with more confidence.
#
# https://data.worldbank.org/indicator/IS.AIR.PSGR?end=2016&start=1970&type=points&view=chart

# %%
df_totalFlight = pd.read_csv('C:\MyStuff\Machine Learning\Kaggle\\aircraftCrashes\API_IS.AIR.PSGR_DS2_en_csv_v2_9908812.csv')
total_flights = df_totalFlight.fillna(0).drop(['Country Name','Country Code','Indicator Name','Indicator Code'],axis=1).sum().to_frame()
total_flights.index = total_flights.index.astype(float)
total_flights = total_flights.drop([1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,2017])
#####################
X = [[i] for i in total_flights.index]
svd_model = SVR(kernel='rbf',C=1e3,gamma= 0.001)
svd_model.fit(X,total_flights.values/1e10)
predict = lambda i : svd_model.predict(i)
p_years = np.arange(1970,2030,1).reshape(-1,1)
p_totalflights = predict(p_years)

plt.figure(figsize=(14, 6))
plt.plot(X,total_flights.values)
plt.plot(p_years,p_totalflights*1e10)
plt.xlim(1970, 2025)
plt.xticks(np.arange(1970,2025,2))
plt.xticks(rotation=45)
plt.ticklabel_format(useOffset=False)
plt.title("Total Flights in the world in millions")
plt.xlabel('Years')
plt.ylabel('Total Flights in Millions')
plt.legend(['Actual','Predicted'])
plt.tight_layout()
plt.show()

p_totalflights = p_totalflights*1e10
df_Flights = pd.DataFrame({'Years': p_years.ravel(),
                                           'Total Flights':p_totalflights,
                                          'TotalCrashes': 0}).set_index('Years')
#move all the crash info from same year to new dataframe
df_Flights['TotalCrashes'].loc[df_Flights.index] = df_flightCrashPrediction.Crashes.reindex(df_Flights.index.values)
df_Flights.fillna(0)
df_Flights['Safety Index'] = (df_Flights['Total Flights'] - df_Flights.TotalCrashes)/df_Flights['Total Flights']*100

# Plotting
plt.figure(figsize=(14, 6))
plt.plot(df_Flights.index.values,df_Flights['Safety Index'].values)
plt.xlim(1970, 2025)
plt.xticks(np.arange(1970,2025,2))
plt.xticks(rotation=45)
plt.ticklabel_format(useOffset=False)
plt.title("Safety Index of flight over Years (Percentage %)")
plt.xlabel('Years')
plt.ylabel('Flight safety measure(%)')
plt.tight_layout()
plt.show()

# %% [markdown]
# <font color='navy'> This graph shows that total number of flights each year are increasing is much higher compared to the number of accidents happening. Even though during mid 19th Century number of flight crashes increased but in comparison to that the number of flights per year have increased at a much more higher rate and therefore the safety index has shown a continously rising trend. As of 2016 and onwards it is almost 100% certain that our next flight will be safe ( with less than 1 in a million chance of any accident). With this information and the analytics deducted above, it can be concluded with much more certainity that it is very safe these day to travel by aircraft.</font>
